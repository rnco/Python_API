# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random

from datetime import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
out_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
# city_df = pd.DataFrame(cities)
# city_df.head()

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
#url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&params&APPID={api_key}"

# %%
# Create empty lists
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# call counter 
record = 1

# Log file print statement
print(f"Lets get this party started!!")
print(f"-------------------------------")


#Loop
for city in cities:  
    
    # Try  to append calls
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Hit {record} | {city_record}")
      

        record= record + 1 
        
    # If no record found "skip" to next call
    except:
        print("WTF")
    continue
# Out:
# Lets get this party started!!
# -------------------------------
# Hit 1 | Mataura
# Hit 2 | Kolosovka
# Hit 3 | Half Moon Bay
# Hit 4 | Albany
# Hit 5 | Perehonivka
# Hit 6 | Kapaa
# Hit 7 | Marand
# Hit 8 | Busselton
# Hit 9 | Kahului
# Hit 10 | Hermanus
# WTF
# Hit 11 | Butaritari
# WTF
# Hit 12 | Kaitangata
# Hit 13 | Bairnsdale
# Hit 14 | Airai
# Hit 15 | Puro
# Hit 16 | Olinda
# Hit 17 | Provideniya
# Hit 18 | Torbay
# Hit 19 | Tuatapere
# Hit 20 | Abu Dhabi
# Hit 21 | Qiongshan
# Hit 22 | Chhapar
# Hit 23 | Cape Town
# Hit 24 | Port Alfred
# Hit 25 | Dikson
# Hit 26 | Qaanaaq
# Hit 27 | Vostochnyy
# Hit 28 | Coquimbo
# Hit 29 | Rikitea
# Hit 30 | San Patricio
# Hit 31 | Monrovia
# Hit 32 | Bereda
# Hit 33 | Bluff
# Hit 34 | Vaini
# Hit 35 | Sao Filipe
# Hit 36 | Upernavik
# Hit 37 | Punta Arenas
# Hit 38 | Tiksi
# WTF
# Hit 39 | San Lorenzo
# Hit 40 | Cabo San Lucas
# WTF
# Hit 41 | Saint-Augustin
# Hit 42 | Cobija
# Hit 43 | Vaitape
# Hit 44 | Vostok
# Hit 45 | Astoria
# Hit 46 | Utica
# Hit 47 | Tromso
# Hit 48 | Ende
# Hit 49 | Arraial do Cabo
# Hit 50 | Qaqortoq
# Hit 51 | Avarua
# Hit 52 | Adrar
# Hit 53 | Nikolskoye
# Hit 54 | Saskylakh
# Hit 55 | Kassala
# Hit 56 | Fukue
# Hit 57 | Nattam
# Hit 58 | Port Blair
# Hit 59 | Ribeira Grande
# Hit 60 | Payo
# Hit 61 | Amazar
# Hit 62 | Ambon
# Hit 63 | Georgetown
# WTF
# Hit 64 | Bethel
# Hit 65 | Severo-Kurilsk
# Hit 66 | Hilo
# Hit 67 | Ponta do Sol
# Hit 68 | Jawhar
# Hit 69 | Sao Jose da Coroa Grande
# Hit 70 | Saldanha
# Hit 71 | Chimbote
# Hit 72 | Vestmanna
# Hit 73 | Ushuaia
# Hit 74 | Mahajanga
# Hit 75 | Barrow
# Hit 76 | Sao Joao da Barra
# Hit 77 | Prince Rupert
# WTF
# Hit 78 | Yeppoon
# WTF
# Hit 79 | New Norfolk
# Hit 80 | Hamilton
# Hit 81 | Boyolangu
# Hit 82 | Port Elizabeth
# Hit 83 | Alyangula
# WTF
# Hit 84 | Guerrero Negro
# Hit 85 | Pangnirtung
# Hit 86 | Mahanoro
# Hit 87 | Sakti
# Hit 88 | Beyneu
# Hit 89 | Ibra
# Hit 90 | Longyearbyen
# Hit 91 | Saint George
# Hit 92 | La Ronge
# Hit 93 | Bangui
# Hit 94 | Starkville
# Hit 95 | Carnarvon
# Hit 96 | Pacific Grove
# Hit 97 | Stillwater
# Hit 98 | Luderitz
# WTF
# Hit 99 | Padang
# Hit 100 | Griffith
# Hit 101 | Staryy Nadym
# Hit 102 | Green Valley
# Hit 103 | Chokurdakh
# Hit 104 | Tarbes
# Hit 105 | Tasiilaq
# Hit 106 | Havoysund
# Hit 107 | Tuktoyaktuk
# Hit 108 | Scottsboro
# Hit 109 | Hobart
# Hit 110 | Geraldton
# Hit 111 | Pedernales
# Hit 112 | Cuamba
# Hit 113 | Takoradi
# WTF
# Hit 114 | Jamestown
# Hit 115 | Toora-Khem
# Hit 116 | Thompson
# Hit 117 | Bredasdorp
# Hit 118 | Atuona
# WTF
# Hit 119 | Castro
# Hit 120 | Hay River
# Hit 121 | Prata
# Hit 122 | Waingapu
# Hit 123 | Pisco
# WTF
# WTF
# Hit 124 | Khatanga
# Hit 125 | Thinadhoo
# Hit 126 | Galle
# Hit 127 | Murgab
# Hit 128 | Muli
# Hit 129 | Sinnamary
# Hit 130 | Bom Jesus
# Hit 131 | Arman
# Hit 132 | Lavrentiya
# WTF
# Hit 133 | Ancud
# Hit 134 | Waipawa
# Hit 135 | Chernyakhovsk
# WTF
# WTF
# Hit 136 | Victoria
# Hit 137 | Kampene
# Hit 138 | Kavaratti
# Hit 139 | Hami
# Hit 140 | Aklavik
# Hit 141 | Mega
# Hit 142 | Freeport
# Hit 143 | Markova
# Hit 144 | College
# Hit 145 | Suriapet
# WTF
# Hit 146 | Vardo
# Hit 147 | Zaysan
# Hit 148 | Narsaq
# Hit 149 | Oistins
# Hit 150 | Kenora
# Hit 151 | Hasaki
# Hit 152 | Sur
# Hit 153 | Mayo
# Hit 154 | Port Lincoln
# Hit 155 | Bambous Virieux
# Hit 156 | Kruisfontein
# Hit 157 | Picota
# Hit 158 | Klaksvik
# Hit 159 | Ayan
# Hit 160 | Chingirlau
# Hit 161 | Zambezi
# Hit 162 | Praia da Vitoria
# WTF
# Hit 163 | Tokmak
# Hit 164 | Te Anau
# Hit 165 | Inhambane
# Hit 166 | Mahebourg
# Hit 167 | Iqaluit
# Hit 168 | Enshi
# Hit 169 | Kendari
# Hit 170 | Mar del Plata
# Hit 171 | Forestville
# Hit 172 | Mkokotoni
# Hit 173 | Pangoa
# Hit 174 | Saint-Philippe
# WTF
# Hit 175 | Farafangana
# Hit 176 | Chulucanas
# Hit 177 | Kimbe
# Hit 178 | Hualmay
# Hit 179 | Lata
# Hit 180 | Bonavista
# Hit 181 | Melilla
# Hit 182 | Juba
# WTF
# Hit 183 | Lompoc
# Hit 184 | Warmbad
# Hit 185 | Terney
# Hit 186 | Kijang
# WTF
# Hit 187 | Zhigansk
# Hit 188 | Kodiak
# Hit 189 | Verkhnevilyuysk
# Hit 190 | Gao
# Hit 191 | Clyde River
# Hit 192 | Broome
# Hit 193 | Suez
# Hit 194 | Aldan
# Hit 195 | Hithadhoo
# Hit 196 | Saint-Leu
# Hit 197 | Tenenkou
# Hit 198 | Merauke
# WTF
# Hit 199 | Fortuna
# WTF
# WTF
# Hit 200 | Leningradskiy
# Hit 201 | Bambari
# Hit 202 | Chuy
# Hit 203 | Lebu
# Hit 204 | Turki
# Hit 205 | San Cristobal
# Hit 206 | Pevek
# Hit 207 | Ust-Nera
# Hit 208 | Buckeye
# Hit 209 | Katobu
# Hit 210 | Russell
# Hit 211 | Ternate
# Hit 212 | Temyasovo
# Hit 213 | Taytay
# WTF
# Hit 214 | Smirnykh
# Hit 215 | Saint-Georges
# Hit 216 | Phayao
# Hit 217 | Los Llanos de Aridane
# Hit 218 | Kibala
# Hit 219 | Korsakovo
# Hit 220 | Vanavara
# WTF
# Hit 221 | Tongren
# Hit 222 | Margate
# WTF
# WTF
# Hit 223 | Mathbaria
# Hit 224 | Buchanan
# Hit 225 | Chenzhou
# Hit 226 | Katsuura
# Hit 227 | Grand-Santi
# Hit 228 | Ilulissat
# Hit 229 | Yellowknife
# WTF
# Hit 230 | San Jose
# Hit 231 | Bafata
# Hit 232 | Xochihuehuetlan
# WTF
# Hit 233 | Salinopolis
# WTF
# Hit 234 | Puerto Ayora
# Hit 235 | Kieta
# Hit 236 | Talnakh
# Hit 237 | Kloulklubed
# Hit 238 | Kourou
# Hit 239 | Sault Sainte Marie
# Hit 240 | Vao
# Hit 241 | Ellisras
# Hit 242 | Grindavik
# WTF
# Hit 243 | Lypova Dolyna
# Hit 244 | Rock Springs
# Hit 245 | Sitka
# Hit 246 | Formosa
# Hit 247 | San-Pedro
# Hit 248 | Juuru
# Hit 249 | Hofn
# Hit 250 | Sola
# Hit 251 | Umm Kaddadah
# WTF
# Hit 252 | Ostrovnoy
# Hit 253 | Kuznechnoye
# Hit 254 | Yamada
# Hit 255 | Pecos
# Hit 256 | Ayagoz
# Hit 257 | Sao Jose de Piranhas
# Hit 258 | Kavieng
# Hit 259 | Paciran
# Hit 260 | Nome
# Hit 261 | Ventspils
# Hit 262 | Sal Rei
# Hit 263 | Namikupa
# WTF
# Hit 264 | Vila Franca do Campo
# Hit 265 | Mattru
# Hit 266 | Oriximina
# Hit 267 | Srostki
# Hit 268 | Tual
# Hit 269 | Wanaka
# Hit 270 | Santa Barbara
# Hit 271 | Brawley
# Hit 272 | Meulaboh
# Hit 273 | Haines Junction
# WTF
# Hit 274 | Kumano
# Hit 275 | Beringovskiy
# WTF
# Hit 276 | Slave Lake
# Hit 277 | Pangkalanbuun
# Hit 278 | Betsiamites
# Hit 279 | Atasu
# Hit 280 | Arroio dos Ratos
# Hit 281 | Sabha
# Hit 282 | Whitehorse
# Hit 283 | Boralday
# Hit 284 | Maumere
# Hit 285 | Whitianga
# Hit 286 | Boende
# Hit 287 | Port Hardy
# Hit 288 | Jieshi
# Hit 289 | Santa Rosa
# Hit 290 | Golden
# Hit 291 | Isangel
# Hit 292 | San Carlos de Bariloche
# Hit 293 | Nowy Dwor Mazowiecki
# Hit 294 | Vung Tau
# Hit 295 | Fuling
# Hit 296 | Alihe
# Hit 297 | Novyy Buh
# Hit 298 | Guanica
# Hit 299 | Rio Gallegos
# Hit 300 | Khorinsk
# Hit 301 | Hwange
# Hit 302 | Fairbanks
# Hit 303 | Tautira
# Hit 304 | General Pico
# Hit 305 | Camacha
# Hit 306 | Saint Anthony
# Hit 307 | Yar-Sale
# Hit 308 | Tiznit
# Hit 309 | Calbe
# Hit 310 | Ipubi
# Hit 311 | Zyryanka
# Hit 312 | Scottsbluff
# Hit 313 | Norman Wells
# Hit 314 | Sao Felix do Xingu
# Hit 315 | Mareeba
# Hit 316 | Lagoa
# Hit 317 | San Matias
# Hit 318 | Esso
# Hit 319 | Constitucion
# Hit 320 | Barmer
# Hit 321 | Cehegin
# WTF
# Hit 322 | Luganville
# Hit 323 | Alice
# Hit 324 | Pahrump
# Hit 325 | Paamiut
# Hit 326 | Serebryanyy Bor
# Hit 327 | East London
# Hit 328 | Araouane
# Hit 329 | Springfield
# Hit 330 | Rome
# Hit 331 | Newcastleton
# Hit 332 | Nalut
# Hit 333 | Ikom
# Hit 334 | Lazaro Cardenas
# Hit 335 | Garissa
# Hit 336 | Faanui
# Hit 337 | Tikhvin
# Hit 338 | Zheleznodorozhnyy
# Hit 339 | Cedar City
# Hit 340 | Sobolevo
# Hit 341 | Mushie
# Hit 342 | Karancslapujto
# Hit 343 | Los Palacios
# Hit 344 | Aguilar de la Frontera
# Hit 345 | Goderich
# Hit 346 | Gorom-Gorom
# Hit 347 | Gondanglegi
# Hit 348 | Vahan
# Hit 349 | Hambantota
# Hit 350 | Namatanai
# Hit 351 | Yulara
# Hit 352 | Nizwa
# Hit 353 | Bagdarin
# Hit 354 | Elko
# Hit 355 | Zalaszentgrot
# WTF
# Hit 356 | Komsomolskiy
# Hit 357 | Bathsheba
# Hit 358 | Fort Morgan
# Hit 359 | Coahuayana
# Hit 360 | Itaituba
# Hit 361 | Aksu
# Hit 362 | Dingle
# Hit 363 | Rawson
# Hit 364 | Altay
# Hit 365 | Ajdabiya
# Hit 366 | The Pas
# Hit 367 | Chojnow
# Hit 368 | Rutul
# Hit 369 | Kljuc
# Hit 370 | Awbari
# Hit 371 | Khuzdar
# Hit 372 | Inverell
# Hit 373 | Shache
# Hit 374 | Umm Lajj
# Hit 375 | Cherskiy
# Hit 376 | Curico
# Hit 377 | Marshall
# Hit 378 | Caravelas
# Hit 379 | Tezu
# Hit 380 | Leshukonskoye
# Hit 381 | Kerema
# Hit 382 | Harper
# Hit 383 | Saint-Joseph
# Hit 384 | Kungurtug
# Hit 385 | Karasjok
# Hit 386 | Flin Flon
# Hit 387 | Vanimo
# Hit 388 | Cayenne
# Hit 389 | Syracuse
# Hit 390 | Mount Gambier
# Hit 391 | Gopalpur
# Hit 392 | Modasa
# Hit 393 | Szigetvar
# Hit 394 | Berdigestyakh
# Hit 395 | Shugurovo
# Hit 396 | Malabo
# Hit 397 | Iranshahr
# Hit 398 | Birao
# WTF
# Hit 399 | Naron
# Hit 400 | Trat
# Hit 401 | Ahipara
# Hit 402 | The Valley
# Hit 403 | Parana
# Hit 404 | Sudak
# Hit 405 | Bondo
# Hit 406 | Gigmoto
# Hit 407 | Ambilobe
# Hit 408 | Port Hawkesbury
# Hit 409 | Marks
# Hit 410 | Grand Gaube

# %%
# Creating dictionary
column_names = {"City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed}

# %%
# Create Dataframe
city_weather_data = pd.DataFrame(column_names)

# Count to make sure all rows are filled
city_weather_data.count()

# %%
city_weather_data.to_csv('weather_data_CSV.csv')

# %%
 #Scatter plot for the selected coordinates  
plt.scatter(city_weather_data.Lng, 
            city_weather_data.Lat,
            edgecolor='black', linewidths=.15, marker="o", 
            alpha=0.5, label="Weather Cities")

# Incorporate the other graph properties
#plt.title("Selected LATS & LNGS")
plt.title(f"City Latitude vs. Humidity")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.12),
          ncol=3, fancybox=True, shadow=True)
plt.grid(True)

# Show plot
plt.show()

# %%
x_axis = city_weather_data['Lat']
y_axis = city_weather_data['Cloudiness']

plt.scatter(x_axis, y_axis, c='navy', edgecolors='black', alpha=1)

plt.title(f"City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("LatitudeVsCloudiness.png")
plt.show()

# %%
x_axis = city_weather_data['Lat']
y_axis = city_weather_data['Wind Speed']

plt.scatter(x_axis, y_axis, c='navy', edgecolors='black', alpha=1)

plt.title(f"City Latitude vs. Wind Speed {datetime.now().strftime('%m/%d/%Y')}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("LatitudeVsWindSpeed.png")
plt.show()
